# %% [markdown]
# # COMP4115: Exploratory Data Analysis and Visualization
# # Lab 5 Excercise on Voted Perceptron
#
# Student Name:
#
# Student Number:

# %% [markdown]
# ![votedPerceptron.png](attachment:votedPerceptron.png)

# %% [markdown]
# ## Q1. Implement the training function of voted perceptron.

# %% [markdown]
# ## Q2. Implement the prediction function of voted perceptron.

# %% [markdown]
# # Q3. Test your voted perceptron algorithm on iris dataset
# - Change the original 3 classes classification into binary classification by: vesicolor to postive class; others to negative class
# - Use a single training/test spliting: 80% as training set and 20% as test set
