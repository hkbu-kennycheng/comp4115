# %% [markdown]
# # COMP4115: Exploratory Data Analysis and Visualization
# # Lab 6 Exercise on Data Classification and Regression
#
# Student Name:
#
# Student Number:

# %% [markdown]
# ### Q1. Import 'data_classification.csv' (x1, x2 are two features, y is the class label).  Perform 10-fold cross-validation on this dataset using SVM with linear kernel. Output the accuracy of 10-fold cross-validation on this dataset.

# %% [markdown]
# ### Q2. Perform 10-fold cross-validation on the dataset using SVM with 'rbf' kernel. Try different parameter settings for C = {0.01, 0.1, 1}. Output the accuracy of 10-fold cross-validation on the dataset with different values of C.

# %% [markdown]
# ### Q3. Perform 10-fold cross-validation on the dataset using multiple-layers perceptron. Try different parameter settings for hidden_layer_sizes = {(50,), (100,)}. Output the accuracy of 10-fold cross-validation on the dataset with different values of hidden_layer_sizes.

# %% [markdown]
# ### Q4. Perform 10-fold cross-validation on the dataset using K nearest neigbhor algorithm. Try different parameter settings for k = {3, 7, 11, 15}. Output the accuracy of 10-fold cross-validation on the dataset with different values of k.

# %% [markdown]
# ### Q5. Import 'diabetes_dataset.csv'. The output variable is the last column (i.e., column 'target'). Use 'bmi' as the only input variable and 'target' as the output variable. Perform linear regression to fit a straight to model the relationship between 'bmi' and 'target'. Visualize this two-dimensional data and the fitted straight line.
# ![diabetes_dataset_desc.png](attachment:diabetes_dataset_desc.png)

# %% [markdown]
# ### Q6. Perform 10-folds cross-validation on the dataset using Ridge Regression. Try different parameter settings for alpha = {1, 10, 100, 1000}. Output the negative mean squared error of 5-fold cross-validation on the dataset with different values of parameter alpha.
